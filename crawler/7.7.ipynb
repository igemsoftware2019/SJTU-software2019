# %%
import re
pattern='A.*B'
m=re.search(pattern,"GAG2B")
print(m.group(0))
print(pattern.search("ABB"))
# Out:
# AG2B
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cd7229d2f4ed> in <module>()
#       3 m=re.search(pattern,"GAG2B")
#       4 print(m.group(0))
# ----> 5 print(pattern.search("ABB"))
#
# AttributeError: 'str' object has no attribute 'search'

# %% [markdown]
# ### 实例练习

# %%
import urllib.request
import urllib
import re

url="http://www.qiushibaike.com/hot/page/1/"
user_agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"
headers1 = {"User-Agent":user_agent}
try:
    request=urllib.request.Request(url,headers=headers1)
    response=urllib.request.urlopen(request)
    #print(response.read())
    content=response.read().decode('utf-8')
    pattern=re.compile('<div class="author clearfix">.*?<h2>(.*?)</h2>.*?<div class="content".*?<span>(.*?)</span>.*?<i class="number">(.*?)<.*?<i class="number">(.*?)</i>',re.S)
    items=re.findall(pattern,content)
    for i in items:
        print("name:"+i[0])
        print("article:"+i[1])
        print("number1:"+i[2])
        print("number2:"+i[3])
        print()
    
except urllib.request.URLError as e:
    if hasattr(e,"code"):
        print(e.code)
    if hasattr(e,"reason"):
        print(e.reason)
# Out:
# name:
# 我不是小蕾
#
# article:
#
#
# 陪闺蜜小蕾去逛街，她在一家服装店看上一件裙子。<br/>可店家老板娘有点强势，闺蜜小蕾讨价还价半天，一分钱也没还下来！<br/>这时候，小蕾眼睛突然一亮 ，她手一抖，一张红票掉在她脚下。<br/>我抬脚想要帮她拾起来，她却突然 给我使了个眼色不让我动弹！<br/>接着，她对老板娘说道，“哎呀哎呀，钱包里就剩一百了，钱不够呢，今天不买了！”<br/>老板娘听小蕾这么一说，忙上前一步，说，“算了算了，见你真心喜欢，给你打个七折，一百卖你了！”<br/>遂，闺蜜喜笑颜开，拉着我痛痛快快结账走人了！<br/>走出店门之后，我恨铁不成钢地对闺蜜说，“小蕾，你
# …
#
# number1:1824
# number2:27
#
# name:
# 兔子威武
#
# article:
#
#
# 午饭点了麻辣香锅，发图跟男友‘汇报’。<br/>男友：少吃那些东西，都是地沟油，吃多不健康。<br/>我问他那吃啥健康？<br/>男友：吃泡面啊，泡面没地沟油！<br/>我…是不是该换男朋友了…
#
#
# number1:2282
# number2:58
#
# name:
# 鱼歌浅唱
#
# article:
#
#
# 单位新来了一位美女，分配在强哥办公室。<br/>然后，来强哥办公室咨询的、办业务的牲口们便乌泱乌泱络绎不绝。<br/>强哥很热情，耐心的给美女逐一介绍：“这个是小张，女朋友也是咱们单位的……这个是小王，已婚……这个是小李，小孩都已经读幼儿园了……”
#
#
# number1:1743
# number2:26
#
# name:
# 再见单身狗
#
# article:
#
#
# 劝表妹别太挑食了，看看差不多就把自己嫁出去得了<br/>表妹也没说话，给我夹了一块儿冬瓜菜<br/>我:你不知道我不喜欢吃冬瓜吗？<br/>表妹:看看，你连自己都说服不了，怎么好意思劝我对付
#
#
# number1:1663
# number2:36
#
# name:
# ［糗百红包］哎
#
# article:
#
#
# 现在的人以为有手机支付就不用带现金了。<br/><br/>不曾想到有的地方偏偏只收现金。<br/><br/>昨天在小卖部买东西就遇到了，一对男女拿了一堆东西准备付款<br/>男：老板多少钱，微信支付<br/><br/>老板：我这里只收现金，不收微信<br/>男的听到一脸懵逼，然后找人看看能不能换点现金<br/>我：要不我换点给你吧<br/><br/>男：好，谢谢兄弟了<br/>我正拿钱出来想到了什么<br/>我：对不起，没有信号换不了<br/>说完就走了<br/><br/>当时在海上，信号什么都没有[哈哈][哈哈][哈哈][哈哈]
#
#
# number1:757
# number2:20
#
# name:
# 随时开火
#
# article:
#
#
# 我就是想问问各位。我吃了止痛药挨打还会疼吗？
#
#
# number1:1698
# number2:136
#
# name:
# 拽着蜗牛去跑步
#
# article:
#
#
# 一女孩指着报纸对男友说：“你看你看，捐精一次可以补助300元。”<br/>男友紧张的问道：“你想怎么样?”<br/>女友说：“如果你受得了的话，我想年内买套房……
#
#
# number1:1707
# number2:42
#
# name:
# 耶路撒冷⊕大尸凶
#
# article:
#
#
# 本人在国外工作媳妇带着孩子去青岛市内办体检。坐汽车到了车站给我打电话问我打不到车怎么办。别笑话我媳妇不会用滴滴打车之类的软件。一个八六年的女人去年才会用微信红包功能。<br/>摊上这么个媳妇我上辈子一定是个无恶不作恶贯满盈之流。<br/>其实我就想问一下有人买媳妇不。倒搭二千块钱包邮。可分多个精美包装。
#
#
# number1:2689
# number2:183
#
# name:
# 义行天下7
#
# article:
#
#
# 儿子出生以后，老婆一直偏向儿子，跟女儿说什么大让小，有什么好吃的除非儿子吃腻了，女儿才才能尝尝！<br/>这天，老婆又买了一包两个装的鸡腿，都给了儿子，儿子“吧唧吧唧”吃的很香，女儿眼巴巴的看着流口水，我忍不住骂我老婆:咱就算是养猪也不能可一头喂吧！<br/>老婆“瞪”了我一眼，没吭声，女儿倒先说话了:弟弟别吃了，给咱爸爸吃！
#
#
# number1:1962
# number2:63
#
# name:
# 啊啊没睡醒
#
# article:
#
#
# 千里送作业，哈哈哈，过个好年
#
#
# number1:243
# number2:1
#
# name:
# 七秒钟的记忆YY
#
# article:
#
#
# 我一哥们典型高富帅，前段时间结婚了，新娘就一般人呵呵还比他大五岁…问他情感经历…哥们开玩笑说，处过一大帮女朋友发现十二生肖里还差一个…新娘属相正合适就试着交往一下……修成正果了[呲牙]
#
#
# number1:3343
# number2:96
#
# name:
# 挖鼻孔的老虎
#
# article:
#
#
# 陪一个客户去ktv，他跟一个妹子毛手毛脚的嬉闹，我比较腼腆，只和身旁的妹子聊天。<br/>后来她说：“小时候家里养了几条金鱼，姐姐伸手进鱼缸去摸，我只在旁边看，结果我爸发现了，收走了我和姐姐的零花钱。”<br/>我说：“哈哈，你挺无辜的。”<br/>她说：“我是想告诉你，不摸也要给钱的。”
#
#
# number1:8594
# number2:117
#
# name:
# vx佛系怪兽君
#
# article:
#
#
# 上班时，办公桌对面的女同事老用穿丝袜的腿蹭我，我实在受不了，给她买了支达克宁。今天问她抹了药膏好点了没！尼玛的理都不理我！什么人嘛真是的！
#
#
# number1:1490
# number2:28
#
# name:
# 正版煮茶
#
# article:
#
#
# 带老人家去体检，我去饮水机取水喝，没有一次性水杯。我问护士有没有水杯，护士说：暂时没有水杯，你要是不介意，我这有干净的尿杯！”<br/>于是，我拿着干净的尿杯倒了一杯，水有点烫，我捏着尿杯等水凉，有位大爷好心提醒我：小伙这个放厕所出口的...  我赶紧一饮而尽，而大爷说了句卧 槽...
#
#
# number1:3650
# number2:46
#
# name:匿名用户
# article:
#
#
# 老公带我出席活动！<br/>等下还要再亲亲小嘴<br/>要亲一个小时
#
#
# number1:215
# number2:0
#
# name:
# 承丶宇
#
# article:
#
#
# 初中时喜欢一个女同学，有次放学我亲了她一下，心想大不了挨一巴掌。但她没打我，马尾辫一甩一甩的跑了。我觉得有戏，回家路上不时傻笑。幻想着我俩一起学习、一起进步、一起考上大学、一起毕业、一起工作，攒够了钱结婚生孩子，男孩像我、女孩像她…正想着该给孩子取什么名字呢？她哥把我拽进巷子揍了一顿。
#
#
# number1:3496
# number2:44
#
# name:
# 捉女妖的天师
#
# article:
#
#
# 我:师傅，为啥那么多户人家都喜欢把外墙刷成白色的<br/>师傅:白色反光呀！屋里就没有那么热了<br/>我:屋顶的防晒网为什么要用黑色的！用白色的岂不是郊果更好？<br/>师傅反手敲了我一下脑袋:哪那么多废话！灰斗都空了，快点！
#
#
# number1:2335
# number2:37
#
# name:
# 漠漠杨
#
# article:
#
#
# 前两天买刮刮乐中了25W，老婆非要拿20W给她弟弟，25W除去个人所得税还剩20W,我还亏了两块的买彩票钱，我现在在想要不要换个老婆[doge]
#
#
# number1:4773
# number2:198
#
# name:
# 说攻
#
# article:
#
#
# 刚刚洗完澡在吹头发，手机响了!让我娘先帮我接一下。。。只见我妈拿起手机看了一下屏幕<br/>伴着银铃般的笑声喊了一嗓子＂爸!＂...<br/>然后楞了3秒，迅速把电话丢给我!<br/>我当时也懵了...拿起电话就说＂喂？姥爷!＂。。。<br/>然后。。。我听见电话那头我爸寂寞的声音＂你们是谁？＂
#
#
# number1:3451
# number2:33
#
# name:
# 帅大叔很黄
#
# article:
#
#
# 交给各位大婶了 我
#
#
# number1:384
# number2:19
#
# name:
# -小门神～
#
# article:
#
#
# 家在农村，小时候喜欢爬到后院围墙上往下撒尿。那天一阵风吹过，就不小心尿到我们村一个二愣子头上，他刚好打那走过。<br/>他要进我家来揍我，我老爹拦住了，又是好烟又是好言相劝，他才放过我。<br/>后来........二愣子秃.!顶!了!<br/>他丫的，这事还要赖在我头上。。。。
#
#
# number1:3007
# number2:63
#
# name:
# 骑着二哈啃黄瓜
#
# article:
#
#
# 公司拔河比赛，我们部门比较弱，人家一拔我们就向前冲，然后我重心不稳，差点摔倒，惊慌失措间拉住前面男生的运动裤，最后还是摔倒了，手里紧紧扯住人家运动裤，露出了本命年红色内裤大屁股。。。。好羞耻。。。。还好不是拉住别的部位。。。。不然估计得被我拽长。。。。
#
#
# number1:3364
# number2:109
#
# name:
# 鱼歌浅唱
#
# article:
#
#
# 周末清晨爬山回来汗透，淋浴后换了新入手的大露背、颈肩双吊带膝上睡裙，假装跑到客厅照镜子，其实想看看我家二货啥反应……<br/>只听二货在身后的厨房里“哇！”的一声惊呼：“这面简直太完美了，翻过来看看另一面！”<br/>我羞答答地转过身，看到这货正在给平底锅里的煎鸡蛋翻面……
#
#
# number1:2363
# number2:56
#
# name:
# 天热打鼓球
#
# article:
#
#
# 小时候姐姐牵着我的小手，带我出去玩。<br/>突然，她甩开我，拼命的往前跑。跑出好远后才对我喊：小心，地上有蛇。<br/>等我低头看时，蛇也看着我，就挨着我的脚。<br/>我很害怕，一动也不敢动。我小心翼翼跟它商量：你要是不咬我，那个姐姐我不要了，以后就认你当姐姐！<br/>后来看新白娘子传奇，每次许仙出来时，我都喊姐夫！
#
#
# number1:1925
# number2:16
#
# name:
# 飞太羊
#
# article:
#
#
# 诚招合伙摆摊人：<br/>时间：明天17点<br/>找个一个繁华热闹街市，<br/>我在街头摆摊卖花、<br/>你在街尾摆摊卖T、<br/>天亮了再去酒店前卖Y。<br/>挣钱五五分、来来来 机不再失、时不再来！
#
#
# number1:263
# number2:1
